# %%
import csv
import os
import pandas as pd
from glob import glob
import sys

# %%
def main():
    
    # --- Pergunta de deseja que retire a primeira linha ---
    while True:
        os.system('clear')
        opcao = input("Deseja retirar a primeira linha (Títulos) a partir do segundo arquivo? (s/n) ")

        if opcao.lower() == "s":
            titulo = False
            break

        if opcao.lower() == "n":
            titulo = True
            break

    # --- Variáveis de controle para saber quantos arquivos e linhas foram juntadas ---
    qtdArquivos = 0;
    qtdLinhas = 0;

    # --- Cria o arquivo que vai juntar todos os arquivos CSV ---
    with open("reembolso_4.csv", "a", encoding="ISO-8859-1") as arquivo:
        # --- Lê todos os arquivos CSV da pasta e joga no arquivo criado ---
        for arquivoCSV in glob("/home/gustavo/Downloads/Redes/Despesas/Teste/*.csv"):
            qtdArquivos += 1
            primeiraLinha = True
            for linha in open(arquivoCSV, "r", encoding="ISO-8859-1"):
                if not titulo and qtdArquivos > 1 and primeiraLinha:
                    primeiraLinha = False
                    continue
                qtdLinhas += 1
                arquivo.write(linha)
        arquivo.close()

    # --- Mensagem de saída ---
    os.system('clear')
    print("Foram juntados "+ str(qtdArquivos) +" arquivos e um total de "+ str(qtdLinhas) +" linhas.")

if __name__ == "__main__":
    main()
# Out:
# Deseja retirar a primeira linha (Títulos) a partir do segundo arquivo? (s/n) s
# Foram juntados 2 arquivos e um total de 1446530 linhas.

# %%
x = pd.read_csv("reembolso_4.csv", delimiter=',', error_bad_lines=False)
# Out:
# /home/gustavo/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
x.columns
# Out:
# Index(['txNomeParlamentar', 'ideCadastro', 'nuCarteiraParlamentar',
#        'nuLegislatura', 'sgUF', 'sgPartido', 'codLegislatura', 'numSubCota',
#        'txtDescricao', 'numEspecificacaoSubCota', 'txtDescricaoEspecificacao',
#        'txtFornecedor', 'txtCNPJCPF', 'txtNumero', 'indTipoDocumento',
#        'datEmissao', 'vlrDocumento', 'vlrGlosa', 'vlrLiquido', 'numMes',
#        'numAno', 'numParcela', 'txtPassageiro', 'txtTrecho', 'numLote',
#        'numRessarcimento', 'vlrRestituicao', 'nuDeputadoId', 'ideDocumento'],
#       dtype='object')

# %%
x
# Out:
#         txNomeParlamentar  ideCadastro  nuCarteiraParlamentar  nuLegislatura  \
# 0                  AVANTE          NaN                    NaN         2015.0
# 1                  AVANTE          NaN                    NaN         2015.0
# 2                  AVANTE          NaN                    NaN         2015.0
# 3                  AVANTE          NaN                    NaN         2015.0
# 4                  AVANTE          NaN                    NaN         2015.0
# 5                  AVANTE          NaN                    NaN         2015.0
# 6                  AVANTE          NaN                    NaN         2015.0
# 7                     DEM          NaN                    NaN         2015.0
# 8                     DEM          NaN                    NaN         2015.0
# 9                     DEM          NaN                    NaN         2015.0
# 10                    DEM          NaN                    NaN         2015.0
# ...

# %%
b = pd.read_csv("/home/gustavo/Downloads/Redes/Despesas/Teste/a_reembolso_2.csv", delimiter=';', error_bad_lines=False)
# Out:
# /home/gustavo/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
b.to_csv("/home/gustavo/Downloads/Redes/Despesas/Teste/teste.csv", sep=',', index=False)

# %%
c.to_csv("/home/gustavo/Downloads/Redes/Despesas/Teste/teste.csv", sep=',', index=False)

# %%
c = pd.read_csv("/home/gustavo/Downloads/Redes/Despesas/Teste/teste.csv", delimiter=',', error_bad_lines=False)
# Out:
# /home/gustavo/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
c
# Out:
#          txNomeParlamentar  ideCadastro  nuCarteiraParlamentar  nuLegislatura  \
# 0        LIDERANÇA DO PSDB          NaN                    NaN         2011.0
# 1        LIDERANÇA DO PSDB          NaN                    NaN         2011.0
# 2        LIDERANÇA DO PSDB          NaN                    NaN         2011.0
# 3        LIDERANÇA DO PSDB          NaN                    NaN         2011.0
# 4        LIDERANÇA DO PSDB          NaN                    NaN         2011.0
# 5        LIDERANÇA DO PSDB          NaN                    NaN         2015.0
# 6        LIDERANÇA DO PSDB          NaN                    NaN         2015.0
# 7        LIDERANÇA DO PSDB          NaN                    NaN         2015.0
# 8        LIDERANÇA DO PSDB          NaN                    NaN         2015.0
# 9        LIDERANÇA DO PSDB          NaN                    NaN         2015.0
# 10       LIDERANÇA DO PSDB          NaN                    NaN         2015.0
# ...

# %%
d = pd.read_csv("/home/gustavo/Downloads/Redes/Despesas/Teste/dados_2018_2.csv", delimiter=',', error_bad_lines=False)
d
# Out:
#              txNomeParlamentar  ideCadastro  nuCarteiraParlamentar  \
# 0                       AVANTE          NaN                    NaN
# 1                       AVANTE          NaN                    NaN
# 2                       AVANTE          NaN                    NaN
# 3                       AVANTE          NaN                    NaN
# 4                       AVANTE          NaN                    NaN
# 5                       AVANTE          NaN                    NaN
# 6                       AVANTE          NaN                    NaN
# 7                          DEM          NaN                    NaN
# 8                          DEM          NaN                    NaN
# 9                          DEM          NaN                    NaN
# 10                         DEM          NaN                    NaN
# 11                         DEM          NaN                    NaN
# 12                         DEM          NaN                    NaN
# ...
